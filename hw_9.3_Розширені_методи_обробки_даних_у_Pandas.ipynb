# %% [markdown]
# <a href="https://colab.research.google.com/github/OlgaZy/Python_for_DA/blob/main/hw_9.3_%D0%A0%D0%BE%D0%B7%D1%88%D0%B8%D1%80%D0%B5%D0%BD%D1%96_%D0%BC%D0%B5%D1%82%D0%BE%D0%B4%D0%B8_%D0%BE%D0%B1%D1%80%D0%BE%D0%B1%D0%BA%D0%B8_%D0%B4%D0%B0%D0%BD%D0%B8%D1%85_%D1%83_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Домашнє завдання до теми "Розширені методи обробки даних у Pandas"

# %% [markdown]
# В цьому домашньому завданні продовжуємо працювати з набором даних `supermarket_sales.csv`.

# %% [markdown]
# 0. Імпортуйте бібліотеку pandas та зчитайте дані у змінну `df` типу `pandas.DataFrame`.

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/DA_in_IT/Data/supermarket_sales.csv')

# %% [markdown]
# 1. Відсортуйте дані за спаданням ціни товара ('Unit price') і виведіть 5 перших рядочків на екран.

# %%
df.sort_values(by = 'Unit price', ascending = False).head(5)
# Out:
#       Invoice ID Branch       City Customer type Gender         Product line  \
# 983  148-41-7930      C  Naypyitaw        Normal   Male    Health and beauty
# 122  219-22-9386      B   Mandalay        Member   Male    Sports and travel
# 930  641-62-7288      B   Mandalay        Normal   Male   Home and lifestyle
# 494  437-53-3084      B   Mandalay        Normal   Male  Fashion accessories
# 283  667-92-0055      A     Yangon        Member   Male    Health and beauty
#
#      Unit price  Quantity  Tax 5%    Total       Date   Time      Payment  \
# 983       99.96         7  34.986  734.706  1/23/2019  10:33         Cash
# 122       99.96         9  44.982  944.622   3/9/2019  17:26  Credit card
# 930       99.92         6  29.976  629.496  3/24/2019  13:33      Ewallet
# 494       99.89         2   9.989  209.769  2/26/2019  11:48      Ewallet
# 283       99.83         6  29.949  628.929   3/4/2019  15:02      Ewallet
#
#        cogs  gross margin percentage  gross income  Rating  Hour
# 983  699.72                 4.761905        34.986     6.1    10
# 122  899.64                 4.761905        44.982     4.2    17
# 930  599.52                 4.761905        29.976     7.1    13
# 494  199.78                 4.761905         9.989     7.1    11
# 283  598.98                 4.761905        29.949     8.5    15

# %% [markdown]
# 2. Знайдіть інвойс (рядок в даних) в категорії товарів `Electronic accessories`, в якому був куплений товар з найбільшою кількістю і найбільшою ціною. Виведіть цей рядок даних на екран.

# %%
filter = (df['Product line'] == 'Electronic accessories')
df[filter].sort_values(by = ['Unit price', 'Quantity'], ascending = False).head(1)
# Out:
#       Invoice ID Branch      City Customer type  Gender  \
# 209  817-69-8206      B  Mandalay        Normal  Female
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 209  Electronic accessories       99.73         9  44.8785  942.4485
#
#          Date   Time      Payment    cogs  gross margin percentage  \
# 209  3/2/2019  19:42  Credit card  897.57                 4.761905
#
#      gross income  Rating  Hour
# 209       44.8785     6.5    19

# %% [markdown]
# 3.1. Створіть нову колонку в даних `Rating Category`, яка визначає категорію рейтингу (`Rating`): високий, середній чи низький за наступним правилом:
# - якщо рейтинг вищий або рівний 8 - то він високий (`High`)
# - якщо рейтинг від 6 (включно) до 8 (не включно) - то він середній (`Medium`)
# - інакше - низький (`Low`).

# %%
df['Rating Category'] = df['Rating'].apply(
    lambda x: 'High' if x >= 8 else ('Medium' if x >= 6 else 'Low')
)

df[['Invoice ID', 'Product line', 'Rating', 'Rating Category']].head(7)
# Out:
#     Invoice ID            Product line  Rating Rating Category
# 0  750-67-8428       Health and beauty     9.1            High
# 1  226-31-3081  Electronic accessories     9.6            High
# 2  631-41-3108      Home and lifestyle     7.4          Medium
# 3  123-19-1176       Health and beauty     8.4            High
# 4  373-73-7910       Sports and travel     5.3             Low
# 5  699-14-3026  Electronic accessories     4.1             Low
# 6  355-53-5943  Electronic accessories     5.8             Low

# %% [markdown]
# 3.2. Виведіть, який відсоток даних становить кожне зі значень категорій рейтингу.

# %%
df['Rating Category'].value_counts(normalize=True)
# Out:
# Rating Category
# Medium    0.356
# High      0.329
# Low       0.315
# Name: proportion, dtype: float64

# %% [markdown]
# 4.1. Запустіть код нижче аби створити змінну `time`. Ця змінна містить час в форматі "година:хвилина". Напишіть функцію `get_hour`, яка буде зі змінної формату як `time` дістати лише години і конвертувати їх у тип `int`.
#
# Запустіть написану функцію на змінній `time` та перевірте правильність роботи функції.

# %%
time = '11:28'

# %%
def get_hour(t):
  hour = pd.to_datetime(t).hour
  # display(type(hour))
  return hour

get_hour(time)
# Out:
# 11

# %% [markdown]
# 4.2. З допомогою функції `get_hour` і метода `DataFrame.apply()` створіть нову колонку `Hour` в нашому наборі даних, яка буде містити години здійснення покупки, обчислені на основі часу здійснення покупки `Time`.

# %%
df['Hour'] = df['Time'].apply(get_hour)

df[['Time', 'Hour']].head(7)
# Out:
#     Time  Hour
# 0  13:08    13
# 1  10:29    10
# 2  13:23    13
# 3  20:33    20
# 4  10:37    10
# 5  18:30    18
# 6  14:36    14

# %% [markdown]
# 4.3. Виведіть кількість значень за кожною годиною покупки і дайте відповідь "О яких годинах найбільше здійснюють покупок покупці і чому на Ваш погляд саме о цих годинах? Чи це слогічно, що найбільше покупок саме в ці години?".

# %%
df.groupby('Hour')['Invoice ID'].count()
# Out:
# Hour
# 10    101
# 11     90
# 12     89
# 13    103
# 14     83
# 15    102
# 16     77
# 17     74
# 18     93
# 19    113
# 20     75
# Name: Invoice ID, dtype: int64

# %% [markdown]
# Пік покупок о 19:00:
# Люди роблять покупки після завершення робочого дня.
#
# Другий пік — обідній час (13:00–15:00): Люди активні під час обідньої перерви, але перерва може в різний час.
#
# Третій  пік о 10:00:
# Початок дня, перші активні дії. Можливо люди мають вільний час для покупок зранку.

# %% [markdown]
# 5. Виведіть середнє значення чеку (`Total`) для покупок в містах, наявних в даних, за допомогою функції `groupby`.

# %%
df.groupby('City')['Total'].mean()
# Out:
# City
# Mandalay     319.872506
# Naypyitaw    337.099715
# Yangon       312.354031
# Name: Total, dtype: float64

# %% [markdown]
# 6. Виведіть кількість покупок, середнє, мінімальне та максимальне значення для загальної суми чеку (Total) в містах, наявних в даних, за допомогою функції groupby.
# Зробіть висновки з цих показників та дайте рекомендації для мережі супермаркетів.

# %%
df.groupby('City').agg( Invoces = ('Invoice ID', 'count'), Mean = ('Total','mean'), Min = ('Total','min'), Maх = ('Total','max') )
# Out:
#            Invoces        Mean      Min      Maх
# City
# Mandalay       332  319.872506  18.6375  1022.49
# Naypyitaw      328  337.099715  10.6785  1042.65
# Yangon         340  312.354031  12.6945  1039.29

# %% [markdown]
# Основні тенденції:
#
# *   Yangon демонструє найбільшу активність за кількістю угод, але середній чек — найменший.
# *   Naypyitaw виділяється найвищим середнім чеком та максимальною сумою продажу, незважаючи на найменшу кількість інвойсів.
# *   Mandalay займає проміжну позицію за всіма показниками.
# *   Розкид між мінімальними та максимальними чеками приблизно схожий для всіх міст, але в Naypyitaw він найбільший, що може свідчити про більш різноманітні продажі у цьому місті.

# %% [markdown]
# 7. Ми внесли деякі зміни в наш набір даних, тож, давайте запишемо результат у файл. Запишіть оновлену версію даних у файл `supermarket_sales_enriched.csv`. Зверніть увагу, аби не записати нічого зайвого, наприклад, індекси рядків нам в файлі не потрібні, оскільки вони стандартні.

# %%
df.to_csv('/content/drive/MyDrive/DA_in_IT/Data/supermarket_sales_enriched.csv', index=False)
